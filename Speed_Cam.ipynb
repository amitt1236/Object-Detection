# %% [markdown]
# <a href="https://colab.research.google.com/github/amitt1236/Speed-cam/blob/main/Speed_Cam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# clone repository for deepsort with yolov4
# !git clone https://github.com/amitt1236/Speed-cam.git
# Out:
# Cloning into 'Speed-cam'...
# remote: Enumerating objects: 190, done.
# remote: Counting objects: 100% (190/190), done.
# remote: Compressing objects: 100% (158/158), done.
# remote: Total 190 (delta 65), reused 77 (delta 22), pack-reused 0
# Receiving objects: 100% (190/190), 138.20 MiB | 20.26 MiB/s, done.
# Resolving deltas: 100% (65/65), done.

# %% [markdown]
# Download video

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=FILEID' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1WjndjsP4t8j-3zTYMeQA9JxsM90G3RLH" -O /content/Speed-cam/video/5.mov && rm -rf /tmp/cookies.txt
# Out:
# --2021-12-19 10:28:53--  https://docs.google.com/uc?export=download&confirm=&id=1WjndjsP4t8j-3zTYMeQA9JxsM90G3RLH
# Resolving docs.google.com (docs.google.com)... 74.125.133.100, 74.125.133.138, 74.125.133.102, ...
# Connecting to docs.google.com (docs.google.com)|74.125.133.100|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-04-1c-docs.googleusercontent.com/docs/securesc/s846sa2mqs83miti82od327j2uemscv6/389d8n0u1ubprnij32v60of0n1ecq92o/1639909725000/03794916228657126876/04892486144677972406Z/1WjndjsP4t8j-3zTYMeQA9JxsM90G3RLH?e=download [following]
# --2021-12-19 10:28:55--  https://doc-04-1c-docs.googleusercontent.com/docs/securesc/s846sa2mqs83miti82od327j2uemscv6/389d8n0u1ubprnij32v60of0n1ecq92o/1639909725000/03794916228657126876/04892486144677972406Z/1WjndjsP4t8j-3zTYMeQA9JxsM90G3RLH?e=download
# Resolving doc-04-1c-docs.googleusercontent.com (doc-04-1c-docs.googleusercontent.com)... 64.233.167.132, 2a00:1450:400c:c0a::84
# ...

# %% [markdown]
# Download Yolo Weights

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1k7VqeH6x-SAV4u9RRr87ZHZDllwTGv6-' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1k7VqeH6x-SAV4u9RRr87ZHZDllwTGv6-" -O /content/Speed-cam/tf_model.zip && rm -rf /tmp/cookies.txt
# Out:
# --2021-12-19 10:29:01--  https://docs.google.com/uc?export=download&confirm=goeC&id=1k7VqeH6x-SAV4u9RRr87ZHZDllwTGv6-
# Resolving docs.google.com (docs.google.com)... 74.125.133.138, 74.125.133.101, 74.125.133.139, ...
# Connecting to docs.google.com (docs.google.com)|74.125.133.138|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0s-b4-docs.googleusercontent.com/docs/securesc/4e63ii63mkvrepr9blv2jdsmtfekhhcf/s712mkiq4fkr3ucun579cddeu4d7vkqi/1639909725000/03794916228657126876/01892076201419697304Z/1k7VqeH6x-SAV4u9RRr87ZHZDllwTGv6-?e=download [following]
# --2021-12-19 10:29:01--  https://doc-0s-b4-docs.googleusercontent.com/docs/securesc/4e63ii63mkvrepr9blv2jdsmtfekhhcf/s712mkiq4fkr3ucun579cddeu4d7vkqi/1639909725000/03794916228657126876/01892076201419697304Z/1k7VqeH6x-SAV4u9RRr87ZHZDllwTGv6-?e=download
# ...

# %%
cd Speed-cam
# Out:
# /content/Speed-cam

# %%
# !unzip tf_model.zip
# !rm -rf tf_model.zip
# Out:
# Archive:  tf_model.zip
#    creating: tf_model/
#    creating: tf_model/yolov4-tiny-416/
#   inflating: tf_model/.DS_Store
#   inflating: __MACOSX/tf_model/._.DS_Store
#    creating: tf_model/yolov4-512/
#   inflating: tf_model/yolov4-tiny-416/.DS_Store
#   inflating: __MACOSX/tf_model/yolov4-tiny-416/._.DS_Store
#    creating: tf_model/yolov4-tiny-416/variables/
#   inflating: tf_model/yolov4-tiny-416/saved_model.pb
#    creating: tf_model/yolov4-tiny-416/assets/
#   inflating: tf_model/yolov4-512/.DS_Store
#   inflating: __MACOSX/tf_model/yolov4-512/._.DS_Store
#    creating: tf_model/yolov4-512/variables/
#   inflating: tf_model/yolov4-512/saved_model.pb
#    creating: tf_model/yolov4-512/assets/
#   inflating: tf_model/yolov4-tiny-416/variables/variables.data-00000-of-00001
#   inflating: tf_model/yolov4-tiny-416/variables/variables.index
#   inflating: tf_model/yolov4-512/variables/variables.data-00000-of-00001
#   inflating: tf_model/yolov4-512/variables/variables.index

# %%
# !python object_tracker.py
# Out:
# Streaming output truncated to the last 5000 lines.
# FPS: 7.01
# Frame #:  1230
# FPS: 7.10
# Frame #:  1231
# FPS: 7.14
# Frame #:  1232
# FPS: 7.08
# Frame #:  1233
# FPS: 7.14
# Frame #:  1234
# FPS: 7.12
# Frame #:  1235
# FPS: 7.06
# Frame #:  1236
# FPS: 6.92
# Frame #:  1237
# FPS: 7.10
# Frame #:  1238
# FPS: 7.11
# Frame #:  1239
# FPS: 7.07
# Frame #:  1240
# FPS: 7.11
# Frame #:  1241
# FPS: 7.05
# Frame #:  1242
# FPS: 7.06
# Frame #:  1243
# FPS: 7.16
# Frame #:  1244
# FPS: 6.78
# Frame #:  1245
# FPS: 7.07
# Frame #:  1246
# FPS: 7.12
# Frame #:  1247
# FPS: 7.20
# Frame #:  1248
# FPS: 7.15
# Frame #:  1249
# FPS: 7.13
# Frame #:  1250
# FPS: 7.14
# Frame #:  1251
# FPS: 7.08
# Frame #:  1252
# FPS: 7.08
# Frame #:  1253
# FPS: 7.15
# Frame #:  1254
# FPS: 7.13
# Frame #:  1255
# FPS: 7.14
# Frame #:  1256
# FPS: 7.01
# Frame #:  1257
# FPS: 7.13
# Frame #:  1258
# FPS: 6.90
# Frame #:  1259
# FPS: 6.87
# Frame #:  1260
# FPS: 7.09
# Frame #:  1261
# FPS: 7.11
# ...

# %% [markdown]
# Display video

# %%
# !ffmpeg -i /video/5-out.avi output.mp4
from IPython.display import HTML
from base64 import b64encode
mp4 = open('output.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

# %%
HTML("""
<video controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
